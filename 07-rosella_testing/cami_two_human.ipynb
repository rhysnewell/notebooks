# %%
source('setup.R')

# %% [markdown]
# # CAMI Human toy

# %%
cami_gi_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/all_bins/checkm.out")
rosella_gi <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/checkm.out")
# rosella_length_gi <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_length_filtered/checkm.out")
# big_gi <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/big_only/checkm.out")
das_gi_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/checkm.out")
das_gi_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/checkm_without_rosella.out")


# cami_uro_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/all_bins/checkm.out")
# rosella_uro <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/rosella_bins/checkm.out")
# # rosella_length_uro <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/rosella_length_filtered/checkm.out")
# # big_uro <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/big_only/checkm.out")
# das_uro_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/checkm.out")
# das_uro_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/checkm_without_rosella.out")
# Out:
# Warning message in fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/all_bins/checkm.out"):
# “Discarded single-line footer: <<[2021-03-11 21:59:17] INFO: { Current stage: 0:06:44.434 || Total: 2:14:06.033 }>>”Warning message in fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/checkm.out"):
# “Discarded single-line footer: <<[2021-03-04 14:33:49] INFO: { Current stage: 0:01:59.473 || Total: 0:41:46.095 }>>”

# %%
cami_air <- generate_plots('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Airways/binning/')

cami_gi <- generate_plots('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/')

cami_oral <- generate_plots('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Oral/binning/')

cami_skin <- generate_plots('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/')

cami_uro <- generate_plots('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/')

# cami_gi_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/all_bins/checkm.out")
# rosella_gi <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/checkm.out")
# das_gi_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/checkm.out")
# das_gi_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/checkm_without_rosella.out")

# cami_oral_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Oral/binning/data/all_bins/checkm.out")
# rosella_oral <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Oral/binning/data/rosella_bins/checkm.out")
# das_oral_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Oral/binning/data/checkm.out")
# das_oral_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Oral/binning/data/checkm_without_rosella.out")

# cami_skin_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/data/all_bins/checkm.out")
# rosella_skin <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/data/rosella_bins/checkm.out")
# das_skin_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/data/checkm.out")
# das_skin_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/data/checkm_without_rosella.out")

# cami_uro_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/all_bins/checkm.out")
# rosella_uro <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/rosella_bins/checkm.out")
# das_uro_all <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/checkm.out")
# das_uro_no_rosella <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_uro/binning/data/checkm_without_rosella.out")
# Out:
# Warning message in fread(all_path):
# “Discarded single-line footer: <<[2021-03-11 16:11:05] INFO: { Current stage: 0:15:59.686 || Total: 5:00:36.478 }>>”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# ...

# %%
cami_skin[[3]]
cami_skin[[4]]
cami_skin[[5]]
# Out:
#   binner             t1  t2  t3  t4  t5
# 1 CONCOCT             61  63  64  64  68
# 2 MaxBin2            180 193 206 210 221
# 3 MetaBAT Sens.       27  28  28  28  29
# 4 MetaBAT Spec.       27  28  28  28  29
# 5 MetaBAT SuperSens.  27  28  28  28  29
# 6 MetaBAT SuperSpec.  29  30  30  30  31
# 7 MetaBAT2           149 163 178 186 197
# 8 Rosella            169 176 187 192 198
# 9 VAMB                60  68  75  84  91
#   binner             t1  t2  t3  t4  t5
# 1 DASTool w/ Rosella 280 298 318 324 331
#   binner              t1  t2  t3  t4  t5
# 1 DASTool w/o Rosella 210 228 244 251 257

# %%
cami_coassembly <- ggarrange(cami_gi[[1]] + labs(y="Completeness"), cami_skin[[1]], cami_uro[[1]], cami_oral[[1]], cami_air[[1]],
                             cami_gi[[2]] + labs(y="Contamination"), cami_skin[[2]], cami_uro[[2]], cami_oral[[2]], cami_air[[2]],
                             labels=c("a", "b", "c", "d", "e", 
                                      "a", "b", "c", "d", "e"),
                             ncol=5, nrow=2, common.legend=T, font.label = list(size = 10, face = "bold"))

ggsave("cami_coassembly.tiff", units="in", width=10, height=6, dpi=600)

# %%
generate_ranks(rosella_air, "rosella")
generate_ranks(cami_air_all, "rosella")
generate_ranks(cami_air_all, "vamb")
generate_ranks(cami_air_all, "metabat2")
generate_ranks(cami_air_all, 'metabat_sens')
generate_ranks(cami_air_all, 'metabat_ssens')
generate_ranks(cami_air_all, 'metabat_sspec')
generate_ranks(cami_air_all, 'maxbin')
generate_ranks(cami_air_all, 'concoct')

# generate_ranks_das(big_gi, "Contigs > 1 Mb")
# generate_ranks_das(rosella_length_gi, "Rosella w/ filter")
generate_ranks_das(das_air_all, "DASTool w/ Rosella")
generate_ranks_das(das_air_no_rosella, "DASTool w/o Rosella")

# rosella_gi[Completeness >= 90 & Contamination <=5, .N]
# rosella_gi[Completeness >= 80 & Contamination <=10, .N]
# rosella_gi[Completeness >= 70 & Contamination <=10, .N]


cami_air_com <- ggplot() + 
    geom_line(data=rosella_air[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=cami_air_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=das_air_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=das_air_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner))

cami_air_con <- ggplot() + 
    geom_line(data=rosella_air[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=cami_air_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=das_air_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=das_air_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner))

ggarrange(cami_air_com, cami_air_con, common.legend=TRUE)
# Out:
# Error in .checkTypos(e, names(x)): Object 'Bin Id' not found amongst [2021-03-08, 11:21:27], INFO:, [CheckM, - and 7 more
# Traceback:
#
# 1. generate_ranks(cami_air_all, "rosella")
# 2. checkm_out[`Bin Id` %like% bin, `:=`(binner, bin)]   # at line 8 of file <text>
# 3. `[.data.table`(checkm_out, `Bin Id` %like% bin, `:=`(binner,
#  .     bin))   # at line 8 of file <text>
# 4. tryCatch(eval(.massagei(isub), x, parent.frame()), error = function(e) .checkTypos(e,
#  .     names(x)))
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. value[[3L]](cond)
# 8. .checkTypos(e, names(x))
# 9. stop("Object '", used, "' not found amongst ", paste(head(ref,
#  .     5L), collapse = ", "), if (length(ref) <= 5L) "" else paste(" and",
#  .     length(ref) - 5L, "more"))

# %%
generate_ranks(rosella_gi, "rosella")
# generate_ranks(cami_gi_all, "rosella")
generate_ranks(cami_gi_all, "vamb")
generate_ranks(cami_gi_all, "metabat2")
generate_ranks(cami_gi_all, 'metabat_sens')
generate_ranks(cami_gi_all, 'metabat_ssens')
generate_ranks(cami_gi_all, 'metabat_sspec')
generate_ranks(cami_gi_all, 'maxbin')
generate_ranks(cami_gi_all, 'concoct')

# generate_ranks_das(big_gi, "Contigs > 1 Mb")
# generate_ranks_das(rosella_length_gi, "Rosella w/ filter")
# generate_ranks_das(das_gi_all, "DASTool w/ Rosella")
generate_ranks_das(das_gi_no_rosella, "DASTool w/o Rosella")

rosella_gi[Completeness >= 90 & Contamination <=5, .N]
rosella_gi[Completeness >= 80 & Contamination <=10, .N]
rosella_gi[Completeness >= 70 & Contamination <=10, .N]


cami_gi_com <- ggplot() + 
    geom_line(data=rosella_gi[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=big_gi[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=rosella_length_gi[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=cami_gi_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=das_gi_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) + 
    geom_line(data=das_gi_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner))

cami_gi_con <- ggplot() + 
    geom_line(data=rosella_gi[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=rosella_length_gi[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=big_gi[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=cami_gi_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=das_gi_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) + 
    geom_line(data=das_gi_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner))

ggarrange(cami_gi_com, cami_gi_con, common.legend=TRUE)
# Out:
# [1] 171
# [1] 179
# [1] 183
# Warning message:
# “Removed 115 rows containing missing values (geom_path).”Warning message:
# “Removed 115 rows containing missing values (geom_path).”Warning message:
# “Removed 115 rows containing missing values (geom_path).”
# plot without title

# %%
generate_ranks(rosella_oral, "rosella")
# generate_ranks(cami_oral_all, "rosella")
# generate_ranks(cami_oral_all, "vamb")
# generate_ranks(cami_oral_all, "metabat2")
# generate_ranks(cami_oral_all, 'metabat_sens')
# generate_ranks(cami_oral_all, 'metabat_ssens')
# generate_ranks(cami_oral_all, 'metabat_sspec')
# generate_ranks(cami_oral_all, 'maxbin')
# generate_ranks(cami_oral_all, 'concoct')

# generate_ranks_das(big_gi, "Contigs > 1 Mb")
# generate_ranks_das(rosella_length_gi, "Rosella w/ filter")
# generate_ranks_das(das_oral_all, "DASTool w/ Rosella")
generate_ranks_das(das_oral_no_rosella, "DASTool w/o Rosella")

# rosella_gi[Completeness >= 90 & Contamination <=5, .N]
# rosella_gi[Completeness >= 80 & Contamination <=10, .N]
# rosella_gi[Completeness >= 70 & Contamination <=10, .N]


cami_oral_com <- ggplot() + 
    geom_line(data=rosella_oral[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=cami_oral_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=das_oral_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) 
    geom_line(data=das_oral_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner))

cami_oral_con <- ggplot() + 
    geom_line(data=rosella_oral[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=cami_oral_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=das_oral_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) 
    geom_line(data=das_oral_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner))

ggarrange(cami_oral_com, cami_oral_con, common.legend=TRUE)
# Out:
# plot without title

# %%
generate_ranks(rosella_skin, "rosella")
# generate_ranks(cami_skin_all, "rosella")
generate_ranks(cami_skin_all, "vamb")
generate_ranks(cami_skin_all, "metabat2")
generate_ranks(cami_skin_all, 'metabat_sens')
generate_ranks(cami_skin_all, 'metabat_ssens')
generate_ranks(cami_skin_all, 'metabat_sspec')
generate_ranks(cami_skin_all, 'maxbin')
generate_ranks(cami_skin_all, 'concoct')

# generate_ranks_das(big_gi, "Contigs > 1 Mb")
# generate_ranks_das(rosella_length_gi, "Rosella w/ filter")
generate_ranks_das(das_skin_all, "DASTool w/ Rosella")
generate_ranks_das(das_skin_no_rosella, "DASTool w/o Rosella")

# rosella_gi[Completeness >= 90 & Contamination <=5, .N]
# rosella_gi[Completeness >= 80 & Contamination <=10, .N]
# rosella_gi[Completeness >= 70 & Contamination <=10, .N]


cami_skin_com <- ggplot() + 
    geom_line(data=rosella_skin[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=cami_skin_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=das_skin_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) + 
    geom_line(data=das_skin_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner))

cami_skin_con <- ggplot() + 
    geom_line(data=rosella_skin[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=cami_skin_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=das_skin_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) + 
    geom_line(data=das_skin_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner))

ggarrange(cami_skin_com, cami_skin_con, common.legend=TRUE)
# Out:
# Error in .checkTypos(e, names(x)): Object 'Bin Id' not found amongst [2021-03-08, 11:04:38], INFO:, [CheckM, - and 7 more
# Traceback:
#
# 1. generate_ranks(cami_skin_all, "vamb")
# 2. checkm_out[`Bin Id` %like% bin, `:=`(binner, bin)]   # at line 8 of file <text>
# 3. `[.data.table`(checkm_out, `Bin Id` %like% bin, `:=`(binner,
#  .     bin))   # at line 8 of file <text>
# 4. tryCatch(eval(.massagei(isub), x, parent.frame()), error = function(e) .checkTypos(e,
#  .     names(x)))
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. value[[3L]](cond)
# 8. .checkTypos(e, names(x))
# 9. stop("Object '", used, "' not found amongst ", paste(head(ref,
#  .     5L), collapse = ", "), if (length(ref) <= 5L) "" else paste(" and",
#  .     length(ref) - 5L, "more"))

# %%
generate_ranks(rosella_uro, "rosella")
# generate_ranks(cami_uro_all, "rosella")
generate_ranks(cami_uro_all, "vamb")
generate_ranks(cami_uro_all, "metabat2")
generate_ranks(cami_uro_all, 'metabat_sens')
generate_ranks(cami_uro_all, 'metabat_ssens')
generate_ranks(cami_uro_all, 'metabat_sspec')
generate_ranks(cami_uro_all, 'maxbin')
generate_ranks(cami_uro_all, 'concoct')

# generate_ranks_das(big_uro, "Contigs > 1 Mb")
# generate_ranks_das(rosella_length_uro, "Rosella w/ filter")
# generate_ranks_das(das_uro_all, "DASTool w/ Rosella")
generate_ranks_das(das_uro_no_rosella, "DASTool w/o Rosella")

rosella_uro[Completeness >= 90 & Contamination <=5, .N]
rosella_uro[Completeness >= 80 & Contamination <=10, .N]
rosella_uro[Completeness >= 70 & Contamination <=10, .N]

cami_uro_com <- ggplot() + 
    geom_line(data=rosella_uro[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=big_uro[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=rosella_length_uro[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
    geom_line(data=cami_uro_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) +
#     geom_line(data=das_uro_all[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner)) + 
    geom_line(data=das_uro_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=com_rank, y=Completeness, color=binner))

cami_uro_con <- ggplot() + 
    geom_line(data=rosella_uro[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=rosella_length_uro[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=big_uro[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
    geom_line(data=cami_uro_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) +
#     geom_line(data=das_uro_all[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner)) + 
    geom_line(data=das_uro_no_rosella[Completeness >= 50 & Contamination <= 10,], aes(x=con_rank, y=Contamination, color=binner))

ggarrange(cami_uro_com, cami_uro_con, common.legend=TRUE)
# Out:
# [1] 93
# [1] 102
# [1] 104
# Warning message:
# “Removed 160 rows containing missing values (geom_path).”Warning message:
# “Removed 160 rows containing missing values (geom_path).”Warning message:
# “Removed 160 rows containing missing values (geom_path).”
# plot without title

# %%
rosella_uro[`Bin Id` %like% "804"]
# Out:
#      Bin Id Marker lineage # genomes # markers # marker sets 0 1 2 3 4 5+
#      Completeness Contamination Strain heterogeneity

# %%
# rosella_skin[Completeness >= 90 & Contamination >=10,]
cami_oral_all
# Out:
#      Unexpected error: <class 'FileNotFoundError'>

# %%
cami_gi_coverages <- fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/rosella_long_coverages.tsv")
# Out:
# Error in fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/rosella_long_coverages.tsv"): File '/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/rosella_long_coverages.tsv' does not exist or is non-readable. getwd()=='/home/n10853499/00-jupyter/07-rosella_testing'
# Traceback:
#
# 1. fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_gi/binning/data/rosella_bins/rosella_long_coverages.tsv")
# 2. stop("File '", file, "' does not exist or is non-readable. getwd()=='",
#  .     getwd(), "'")
