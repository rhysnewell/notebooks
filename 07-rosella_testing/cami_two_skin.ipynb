# %%
source('setup.R')

# %%
# Sys.glob(file.path("/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_*/data/all_bins/checkm.out"))

skin_s1 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_1/')
skin_s13 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_13/')
skin_s14 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_14/')
skin_s15 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_15/')
skin_s16 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_16/')
skin_s17 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_17/')
skin_s18 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_18/')
skin_s19 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_19/')
skin_s20 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_20/')
skin_s28 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_28/')
# Out:
# Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-19 23:39:27] INFO: { Current stage: 0:01:48.797 || Total: 1:20:48.319 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-20 02:17:04] INFO: { Current stage: 0:01:14.877 || Total: 0:50:52.738 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-19 22:52:24] INFO: { Current stage: 0:01:12.874 || Total: 0:48:11.199 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-20 00:28:14] INFO: { Current stage: 0:01:32.594 || Total: 1:06:22.926 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-19 22:36:40] INFO: { Current stage: 0:00:46.797 || Total: 0:33:01.163 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-20 00:18:11] INFO: { Current stage: 0:01:35.153 || Total: 1:13:46.447 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# ...
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(all_path):
# “Discarded single-line footer: <<[2022-01-20 05:40:12] INFO: { Current stage: 0:00:33.696 || Total: 0:24:27.501 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella             MaxBin2
#           "#F8766D"           "#D89000"           "#A3A500"           "#39B600"
#       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.  MetaBAT SuperSpec.
#           "#00BF7D"           "#00BFC4"           "#00B0F6"           "#9590FF"
#            MetaBAT2                VAMB             Rosella
#           "#E76BF3"           "#FF62BC"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”

# %%
skin_s1_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_1/', skin_s1)
skin_s13_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_13/', skin_s13)
skin_s14_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_14/', skin_s14)
skin_s15_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_15/', skin_s15)
skin_s16_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_16/', skin_s16)
skin_s17_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_17/', skin_s17)
skin_s18_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_18/', skin_s18)
skin_s19_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_19/', skin_s19)
skin_s20_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_20/', skin_s20)
skin_s28_refined <- add_refine('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/sample_28/',skin_s28)
# Out:
# Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:08:14] INFO: { Current stage: 0:00:05.353 || Total: 0:08:45.120 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:13:42] INFO: { Current stage: 0:00:08.903 || Total: 0:11:41.007 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:21:06] INFO: { Current stage: 0:00:06.627 || Total: 0:09:45.224 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined                VAMB
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#FF62BC"
#             Rosella     Rosella Refined
#           "#000000"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:17:13] INFO: { Current stage: 0:00:07.367 || Total: 0:10:10.870 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:34:06] INFO: { Current stage: 0:00:10.649 || Total: 0:13:38.239 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:06:41] INFO: { Current stage: 0:00:00.607 || Total: 0:03:48.154 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined                VAMB
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#FF62BC"
#             Rosella     Rosella Refined
#           "#000000"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:16:11] INFO: { Current stage: 0:00:01.220 || Total: 0:07:12.264 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:17:35] INFO: { Current stage: 0:00:05.034 || Total: 0:08:05.897 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined             Rosella
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#000000"
#     Rosella Refined
#           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:53:06] INFO: { Current stage: 0:00:09.449 || Total: 0:08:42.588 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:55:52] INFO: { Current stage: 0:00:06.825 || Total: 0:09:52.976 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:45:38] INFO: { Current stage: 0:00:04.388 || Total: 0:08:39.225 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined                VAMB
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#FF62BC"
#             Rosella     Rosella Refined
#           "#000000"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:32:26] INFO: { Current stage: 0:00:01.380 || Total: 0:06:57.056 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:35:51] INFO: { Current stage: 0:00:06.581 || Total: 0:09:52.243 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined             Rosella
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#000000"
#     Rosella Refined
#           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:06:28] INFO: { Current stage: 0:00:09.537 || Total: 0:12:58.625 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:13:45] INFO: { Current stage: 0:00:15.390 || Total: 0:16:42.747 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:14:41] INFO: { Current stage: 0:00:00.943 || Total: 0:06:02.942 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined             Rosella
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#000000"
#     Rosella Refined
#           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:43:56] INFO: { Current stage: 0:00:01.009 || Total: 0:06:44.508 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 18:46:28] INFO: { Current stage: 0:00:02.748 || Total: 0:07:33.232 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined             Rosella
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#000000"
#     Rosella Refined
#           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:33:34] INFO: { Current stage: 0:00:26.561 || Total: 0:22:30.302 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:49:37] INFO: { Current stage: 0:00:33.757 || Total: 0:26:03.397 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:50:10] INFO: { Current stage: 0:00:08.786 || Total: 0:09:26.680 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined                VAMB
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#FF62BC"
#             Rosella     Rosella Refined
#           "#000000"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_rosella/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 20:08:51] INFO: { Current stage: 0:00:14.780 || Total: 0:14:03.490 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 20:26:55] INFO: { Current stage: 0:00:28.774 || Total: 0:21:17.890 }>>”Warning message in fread(paste0(out_path, "/data/rosella_refine_das_tool/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 19:54:27] INFO: { Current stage: 0:00:08.416 || Total: 0:09:07.765 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined                VAMB
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#FF62BC"
#             Rosella     Rosella Refined
#           "#000000"           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Warning message in fread(paste0(out_path, "/data/rosella_refine_metabat2/checkm.out")):
# “Discarded single-line footer: <<[2022-02-03 21:12:21] INFO: { Current stage: 0:00:01.423 || Total: 0:06:45.325 }>>”
#             CONCOCT  DASTool w/ Rosella DASTool w/o Rosella     DASTool Refined
#           "#F8766D"           "#D89000"           "#A3A500"           "#D89000"
#             MaxBin2       MetaBAT Sens.       MetaBAT Spec.  MetaBAT SuperSens.
#           "#39B600"           "#00BF7D"           "#00BFC4"           "#00B0F6"
#  MetaBAT SuperSpec.            MetaBAT2    MetaBAT2 Refined             Rosella
#           "#9590FF"           "#E76BF3"           "#E76BF3"           "#000000"
#     Rosella Refined
#           "#000000"
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t4, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t5, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”

# %%
cami_skin <- ggarrange(skin_s1_refined[[1]] + labs(y="Completeness"), skin_s13_refined[[1]], skin_s14_refined[[1]], skin_s15_refined[[1]], skin_s16_refined[[1]],
                       skin_s1_refined[[2]] + labs(y="Contamination"), skin_s13_refined[[2]], skin_s14_refined[[2]], skin_s15_refined[[2]], skin_s16_refined[[2]], 
                       skin_s17_refined[[1]], skin_s18_refined[[1]], skin_s19_refined[[1]], skin_s20_refined[[1]], skin_s28_refined[[1]],
                       skin_s17_refined[[2]], skin_s18_refined[[2]], skin_s19_refined[[2]], skin_s20_refined[[2]], skin_s28_refined[[2]], 
                       labels=c("1", "13", "14", "15", "16", 
                                "1", "13", "14", "15", "16", 
                                "17", "18", "19", "20", "28",                               
                                "17", "18", "19", "20", "28"),
                       ncol=5, nrow=4, common.legend=T, font.label = list(size = 10, face = "bold"))

ggsave("cami_skin_per_sample.png", units="in", width=10, height=11, dpi=600)

# %%
ggarrange(s1[[1]], s1[[2]], common.legend=T)
s1[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            22 22 22 23 23
# 2 MaxBin2            21 22 23 23 23
# 3 MetaBAT Sens.      25 27 29 29 29
# 4 MetaBAT Spec.      26 28 30 30 30
# 5 MetaBAT SuperSens. 25 27 29 29 29
# 6 MetaBAT SuperSpec. 25 27 27 27 27
# 7 MetaBAT2           29 32 34 36 39
# 8 Rosella            31 32 34 36 38
# 9 VAMB               19 20 21 22 22
# plot without title

# %%
ggarrange(s13[[1]], s13[[2]], common.legend=T)
s13[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT             5  6  6  7 12
# 2 MaxBin2             8 11 11 12 14
# 3 MetaBAT Sens.      17 17 17 18 20
# 4 MetaBAT Spec.      17 17 17 18 20
# 5 MetaBAT SuperSens. 17 17 17 18 20
# 6 MetaBAT SuperSpec. 10 10 10 11 13
# 7 MetaBAT2            6  8  8  9 11
# 8 Rosella            18 21 21 22 24
# 9 VAMB                1  3  3  4  4
# plot without title

# %%
ggarrange(s14[[1]], s14[[2]], common.legend=T)
s14[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            12 13 13 13 15
# 2 MaxBin2            17 17 17 18 19
# 3 MetaBAT Sens.      31 33 34 34 34
# 4 MetaBAT Spec.      31 33 34 34 34
# 5 MetaBAT SuperSens. 31 33 34 34 34
# 6 MetaBAT SuperSpec. 16 17 18 18 18
# 7 MetaBAT2           17 18 18 18 19
# 8 Rosella            20 21 22 22 24
# 9 VAMB                0  0  0  0  0
# plot without title

# %%
ggarrange(s15[[1]], s15[[2]], common.legend=T)
s15[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            10 10 11 11 11
# 2 MaxBin2             8  8  9  9 11
# 3 MetaBAT Sens.      24 24 25 26 29
# 4 MetaBAT Spec.      24 24 25 26 29
# 5 MetaBAT SuperSens. 24 24 25 26 29
# 6 MetaBAT SuperSpec. 15 15 15 15 17
# 7 MetaBAT2           11 11 11 13 14
# 8 Rosella            16 16 17 18 20
# 9 VAMB                6  6  6  6  6
# plot without title

# %%
ggarrange(s16[[1]], s16[[2]], common.legend=T)
s16[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT             5  5  5  5  5
# 2 MaxBin2             7  7  7  7  8
# 3 MetaBAT Sens.      25 26 26 26 26
# 4 MetaBAT Spec.      25 26 26 26 26
# 5 MetaBAT SuperSens. 25 26 26 26 26
# 6 MetaBAT SuperSpec.  3  4  4  4  4
# 7 MetaBAT2            6  6  6  6  6
# 8 Rosella            35 35 35 36 37
# 9 VAMB                0  0  0  0  0
# plot without title

# %%
ggarrange(s17[[1]], s17[[2]], common.legend=T)
s17[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            15 16 16 17 19
# 2 MaxBin2            14 15 15 15 17
# 3 MetaBAT Sens.      23 23 26 28 32
# 4 MetaBAT Spec.      23 23 26 28 32
# 5 MetaBAT SuperSens. 23 23 26 28 32
# 6 MetaBAT SuperSpec. 14 14 15 16 17
# 7 MetaBAT2           26 27 29 29 31
# 8 Rosella            26 27 28 28 32
# 9 VAMB                0  0  0  0  0
# plot without title

# %%
ggarrange(s18[[1]], s18[[2]], common.legend=T)
s18[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            17 17 17 17 17
# 2 MaxBin2            17 17 17 17 17
# 3 MetaBAT Sens.      15 15 16 16 16
# 4 MetaBAT Spec.      15 15 16 16 16
# 5 MetaBAT SuperSens. 15 15 16 16 16
# 6 MetaBAT SuperSpec. 15 15 16 16 16
# 7 MetaBAT2           18 18 18 18 18
# 8 Rosella            45 45 46 46 46
# 9 VAMB                0  0  0  0  0
# plot without title

# %%
ggarrange(s19[[1]], s19[[2]], common.legend=T)
s19[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            20 22 23 23 23
# 2 MaxBin2            33 35 36 37 40
# 3 MetaBAT Sens.      30 31 31 31 35
# 4 MetaBAT Spec.      30 31 31 31 35
# 5 MetaBAT SuperSens. 30 31 31 31 35
# 6 MetaBAT SuperSpec. 30 32 32 33 37
# 7 MetaBAT2           44 48 50 54 61
# 8 Rosella            40 47 51 57 62
# 9 VAMB               14 21 24 28 33
# plot without title

# %%
ggarrange(s20[[1]], s20[[2]], common.legend=T)
s20[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT            23 33 41 43 44
# 2 MaxBin2            24 32 40 41 44
# 3 MetaBAT Sens.      29 29 30 31 36
# 4 MetaBAT Spec.      29 29 30 31 36
# 5 MetaBAT SuperSens. 29 29 30 31 36
# 6 MetaBAT SuperSpec. 18 18 18 19 21
# 7 MetaBAT2           31 39 53 56 57
# 8 Rosella            28 39 45 50 54
# 9 VAMB               20 22 27 30 39
# plot without title

# %%
ggarrange(s28[[1]], s28[[2]], common.legend=T)
s28[[3]]
# Out:
#   binner             t1 t2 t3 t4 t5
# 1 CONCOCT             1  1  1  1  1
# 2 MaxBin2            10 11 11 11 11
# 3 MetaBAT Sens.      13 13 13 13 13
# 4 MetaBAT Spec.      13 13 13 13 13
# 5 MetaBAT SuperSens. 13 13 13 13 13
# 6 MetaBAT SuperSpec. 13 13 13 13 13
# 7 MetaBAT2            6  7  7  7  7
# 8 Rosella            23 23 23 23 23
# 9 VAMB                0  0  0  0  0
# plot without title

# %%
s15_all <- fread('/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/sample_15/data/all_bins/checkm.out')
ranks_for_all(s15_all)
# Out:
# Warning message in fread("/lustre/scratch/microbiome/n10853499/98-CAMI/08-human_toy/CAMI_Skin/binning/sample_15/data/all_bins/checkm.out"):
# “Discarded single-line footer: <<[2021-03-04 18:08:35] INFO: { Current stage: 0:01:30.680 || Total: 1:12:55.901 }>>”

# %%
s15_all[binner %like% "rosella"]
# Out:
#     Bin Id           Marker lineage                   # genomes # markers
# 1   rosella_bin.1    root (UID1)                      5656       56
# 2   rosella_bin.1028 o__Actinomycetales (UID1812)      229      457
# 3   rosella_bin.1029 o__Actinomycetales (UID1530)      622      258
# 4   rosella_bin.11   c__Bacilli (UID285)               586      324
# 5   rosella_bin.1719 g__Staphylococcus (UID301)         45      940
# 6   rosella_bin.1769 k__Bacteria (UID203)             5449      104
# 7   rosella_bin.2    f__Burkholderiaceae (UID4003)      91      596
# 8   rosella_bin.2002 k__Bacteria (UID203)             5449      104
# 9   rosella_bin.2010 g__Staphylococcus (UID301)         45      940
# 10  rosella_bin.2011 g__Staphylococcus (UID298)         56      805
# 11  rosella_bin.26   c__Alphaproteobacteria (UID3422)   26      529
# 12  rosella_bin.2964 o__Actinomycetales (UID1812)      229      457
# 13  rosella_bin.2966 g__Staphylococcus (UID298)         56      805
# 14  rosella_bin.3    root (UID1)                      5656       56
# 15  rosella_bin.36   c__Alphaproteobacteria (UID3422)   26      529
# 16  rosella_bin.3717 g__Staphylococcus (UID301)         45      940
# 17  rosella_bin.3736 g__Staphylococcus (UID301)         45      940
# 18  rosella_bin.3806 g__Staphylococcus (UID294)         60      773
# 19  rosella_bin.3808 g__Staphylococcus (UID294)         60      773
# 20  rosella_bin.3810 o__Actinomycetales (UID1812)      229      457
# 21  rosella_bin.3811 k__Bacteria (UID203)             5449      104
# 22  rosella_bin.3815 k__Bacteria (UID203)             5449      104
# 23  rosella_bin.3817 o__Actinomycetales (UID1812)      229      457
# 24  rosella_bin.3819 root (UID1)                      5656       56
# 25  rosella_bin.3820 f__Streptococcaceae (UID545)      240      524
# 26  rosella_bin.3821 f__Streptococcaceae (UID545)      240      524
# 27  rosella_bin.3822 root (UID1)                      5656       56
# 28  rosella_bin.3824 k__Bacteria (UID203)             5449      104
# 29  rosella_bin.3825 k__Bacteria (UID203)             5449      104
# 30  rosella_bin.3826 root (UID1)                      5656       56
# ... ...              ...                              ...       ...
# 38  rosella_bin.3851 g__Staphylococcus (UID301)         45      940
# 39  rosella_bin.3852 g__Staphylococcus (UID301)         45      940
# 40  rosella_bin.3853 root (UID1)                      5656       56
# 41  rosella_bin.3854 root (UID1)                      5656       56
# 42  rosella_bin.3856 k__Bacteria (UID203)             5449      104
# 43  rosella_bin.3857 root (UID1)                      5656       56
# 44  rosella_bin.3858 root (UID1)                      5656       56
# 45  rosella_bin.3859 k__Bacteria (UID203)             5449      104
# 46  rosella_bin.3860 root (UID1)                      5656       56
# 47  rosella_bin.3862 g__Staphylococcus (UID301)         45      940
# 48  rosella_bin.3863 g__Staphylococcus (UID301)         45      940
# 49  rosella_bin.3864 o__Actinomycetales (UID1812)      229      457
# 50  rosella_bin.3865 root (UID1)                      5656       56
# 51  rosella_bin.4    root (UID1)                      5656       56
# 52  rosella_bin.46   root (UID1)                      5656       56
# 53  rosella_bin.51   g__Staphylococcus (UID301)         45      940
# 54  rosella_bin.58   root (UID1)                      5656       56
# 55  rosella_bin.63   root (UID1)                      5656       56
# 56  rosella_bin.67   g__Staphylococcus (UID301)         45      940
# 57  rosella_bin.7    root (UID1)                      5656       56
# 58  rosella_bin.71   k__Bacteria (UID203)             5449      104
# 59  rosella_bin.72   k__Bacteria (UID203)             5449      104
# 60  rosella_bin.73   g__Staphylococcus (UID294)         60      773
# 61  rosella_bin.739  root (UID1)                      5656       56
# 62  rosella_bin.781  k__Bacteria (UID203)             5449      104
# 63  rosella_bin.8    k__Bacteria (UID203)             5449      104
# 64  rosella_bin.80   g__Staphylococcus (UID301)         45      940
# 65  rosella_bin.81   g__Staphylococcus (UID301)         45      940
# 66  rosella_bin.82   g__Staphylococcus (UID301)         45      940
# 67  rosella_bin.987  root (UID1)                      5656       56
#     # marker sets 0   1   2   3   4   5+  Completeness Contamination
# 1    24             0   0   1  0  53  2   100.00       307.41
# 2   227             3 453   1  0   0  0    99.12         0.44
# 3   152             3 255   0  0   0  0    98.79         0.00
# 4   180            87 234   3  0   0  0    74.31         1.25
# 5   178             4 872  64  0   0  0    99.51         7.03
# 6    58             1  76  27  0   0  0    98.28        20.69
# 7   218             1 591   4  0   0  0    99.94         0.69
# 8    58            61  13  14  6  10  0    65.52        84.48
# 9   178             4 935   1  0   0  0    99.51         0.08
# 10  176             3 802   0  0   0  0    99.61         0.00
# 11  308           106 420   3  0   0  0    77.34         0.54
# 12  227             3 454   0  0   0  0    99.12         0.00
# 13  176            22 401 382  0   0  0    97.79        45.31
# 14   24             0   0   1 55   0  0   100.00       195.83
# 15  308           286 243   0  0   0  0    51.42         0.00
# 16  178           630 302   8  0   0  0    34.49         0.37
# 17  178           315 624   1  0   0  0    62.99         0.08
# 18  178           375 398   0  0   0  0    53.21         0.00
# 19  178             2 771   0  0   0  0    99.73         0.00
# 20  227           388  69   0  0   0  0    15.28         0.00
# 21   58            37  32  28  7   0  0    75.86        43.97
# 22   58            95   9   0  0   0  0     5.09         0.00
# 23  227           409  48   0  0   0  0    10.18         0.00
# 24   24            56   0   0  0   0  0     0.00         0.00
# 25  282           227 297   0  0   0  0    51.95         0.00
# 26  282           379 145   0  0   0  0    27.26         0.00
# 27   24            56   0   0  0   0  0     0.00         0.00
# 28   58            96   8   0  0   0  0    12.07         0.00
# 29   58            95   9   0  0   0  0    13.79         0.00
# 30   24            56   0   0  0   0  0     0.00         0.00
# ... ...           ... ... ... ... ... ... ...          ...
# 38  178           726 191  21   2   0   0  14.43         1.05
# 39  178           618 280  40   2   0   0  38.20         5.16
# 40   24            10   1   2  16  27   0  58.33       122.69
# 41   24            56   0   0   0   0   0   0.00         0.00
# 42   58            82  19   3   0   0   0  23.04         5.17
# 43   24            52   4   0   0   0   0  16.67         0.00
# 44   24            56   0   0   0   0   0   0.00         0.00
# 45   58            93  11   0   0   0   0   6.90         0.00
# 46   24            56   0   0   0   0   0   0.00         0.00
# 47  178           765 175   0   0   0   0  21.29         0.00
# 48  178           789 151   0   0   0   0  17.32         0.00
# 49  227             3 454   0   0   0   0  99.52         0.00
# 50   24            56   0   0   0   0   0   0.00         0.00
# 51   24             0   0  56   0   0   0 100.00       100.00
# 52   24             0   0  55   1   0   0 100.00       100.46
# 53  178           740 112  34  25  22   7  32.55        48.07
# 54   24            45   1   4   4   2   0  45.83        75.00
# 55   24             0   0   0   2  40  14 100.00       310.04
# 56  178           220 187 165 181 117  70  64.14        90.71
# 57   24             0   0   1  55   0   0 100.00       195.83
# 58   58             1  72  24   4   0   3  98.28        50.00
# 59   58            37  25  34   0   3   5  43.10        63.79
# 60  178             1 482  90  26  39 135  99.81       127.41
# 61   24             0   0  53   3   0   0 100.00       112.50
# 62   58             1  27  76   0   0   0  98.28        77.59
# 63   58             0   5  98   1   0   0 100.00        98.96
# 64  178             4 935   1   0   0   0  99.51         0.08
# 65  178             5 934   1   0   0   0  99.48         0.08
# 66  178             4 935   1   0   0   0  99.51         0.08
# 67   24             0   1   2  42   0  11 100.00       279.17
#     Strain heterogeneity binner  com_rank con_rank
# 1     4.13               rosella NA       NA
# 2     0.00               rosella 11       14
# 3     0.00               rosella 12        5
# 4     0.00               rosella 14       17
# 5    98.44               rosella  8       18
# 6   100.00               rosella NA       NA
# 7     0.00               rosella  1       16
# 8   100.00               rosella NA       NA
# 9     0.00               rosella  6       10
# 10    0.00               rosella  3        2
# 11    0.00               rosella 13       15
# 12    0.00               rosella 10        4
# 13   29.58               rosella NA       NA
# 14   74.10               rosella NA       NA
# 15    0.00               rosella 18        8
# 16  100.00               rosella NA       NA
# 17    0.00               rosella 15       13
# 18    0.00               rosella 16        6
# 19    0.00               rosella  2        1
# 20    0.00               rosella NA       NA
# 21  100.00               rosella NA       NA
# 22    0.00               rosella NA       NA
# 23    0.00               rosella NA       NA
# 24    0.00               rosella NA       NA
# 25    0.00               rosella 17        7
# 26    0.00               rosella NA       NA
# 27    0.00               rosella NA       NA
# 28    0.00               rosella NA       NA
# 29    0.00               rosella NA       NA
# 30    0.00               rosella NA       NA
# ... ...                  ...     ...      ...
# 38  100.00               rosella NA       NA
# 39   82.61               rosella NA       NA
# 40  100.00               rosella NA       NA
# 41    0.00               rosella NA       NA
# 42  100.00               rosella NA       NA
# 43    0.00               rosella NA       NA
# 44    0.00               rosella NA       NA
# 45    0.00               rosella NA       NA
# 46    0.00               rosella NA       NA
# 47    0.00               rosella NA       NA
# 48    0.00               rosella NA       NA
# 49    0.00               rosella  4        3
# 50    0.00               rosella NA       NA
# 51    1.79               rosella NA       NA
# 52   98.28               rosella NA       NA
# 53  100.00               rosella NA       NA
# 54  100.00               rosella NA       NA
# 55   99.74               rosella NA       NA
# 56   99.59               rosella NA       NA
# 57   93.98               rosella NA       NA
# 58  100.00               rosella NA       NA
# 59   91.04               rosella NA       NA
# 60   66.67               rosella NA       NA
# 61  100.00               rosella NA       NA
# 62  100.00               rosella NA       NA
# 63   99.01               rosella NA       NA
# 64    0.00               rosella  6       10
# 65    0.00               rosella  9       12
# 66    0.00               rosella  6       10
# 67  100.00               rosella NA       NA
