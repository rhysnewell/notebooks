# %%
library(data.table)
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
anme_ret = fread("/work2/microbiome/abisko/rhys/01-projects/02-anme/02-longreads/02.2-retentate/binning_testing/data/coverm.cov")
anme_fil = fread("/work/microbiome/abisko/rhys/01-projects/02-anme/02-longreads/01.1-filtrate/binning_testing_80/data/coverm.cov")
ega = fread("/lustre/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ega_18-Q3-R5-49/data/coverm.cov")
mari = fread("/lustre/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Mari_18-Q3-R65-66/data/coverm.cov")
low = fread("/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/00-low_complexity/binning/data/coverm.cov")
med = fread("/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/01-med_complexity/binning/data/coverm.cov")

# %%
ggplot(data=anme_ret['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(bins=100) +
    geom_density() + 
    scale_x_continuous(trans="log10")
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title

# %%
ggplot(data=anme_fil['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(binwidth=.1) +
    geom_density() +
    scale_x_continuous(trans='log10')
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title

# %%
ggplot(data=ega['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(aes(y=..density..), binwidth=.1) +
    geom_density() +
    scale_x_continuous(trans='log10')
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title

# %%
ggplot(data=mari['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(aes(y=..density..), binwidth=.1) +
    geom_density() +
    scale_x_continuous(trans='log10')
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title

# %%
ggplot(data=low['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(aes(y=..density..), binwidth=.1) +
    geom_density() +
    scale_x_continuous(trans='log10')
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title

# %%
ggplot(data=med['contigLen' >= 1500], aes(x=contigLen, weight=contigLen)) +
    geom_histogram(aes(y=..density..), binwidth=.1) +
    geom_density() +
    scale_x_continuous(trans='log10')
# Out:
# Warning message in density.default(x, weights = w, bw = bw, adjust = adjust, kernel = kernel, :
# “sum(weights) != 1  -- will not get true density”
# plot without title
