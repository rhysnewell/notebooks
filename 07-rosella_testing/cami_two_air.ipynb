# %%
source('setup.R')

# %%
Sys.glob(file.path("/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_*/data/all_bins/checkm.out"))

air_s4 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4/')
air_s7 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_7/')
air_s8 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_8/')
air_s9 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_9/')
air_s10 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_10/')
air_s11 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_11/')
air_s12 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_12/')
air_s23 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_23/')
air_s26 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_26/')
air_s27 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_27/')
# Out:
# character(0)
# Error in fread(all_path): File '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4//data/all_bins/checkm.out' does not exist or is non-readable. getwd()=='/mnt/home/n10853499/00-jupyter/07-rosella_testing'
# Traceback:
#
# 1. generate_plots("//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4/")
# 2. fread(all_path)
# 3. stop("File '", file, "' does not exist or is non-readable. getwd()=='",
#  .     getwd(), "'")

# %%
air_s4_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4/', air_s4)
air_s7_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_7/', air_s7)
air_s8_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_8/', air_s8)
air_s9_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_9/', air_s9)
air_s10_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_10/', air_s10)
air_s11_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_11/', air_s11)
air_s12_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_12/', air_s12)
air_s23_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_23/', air_s23)
air_s26_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_26/', air_s26)
air_s27_refined <- add_refine('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_27/', air_s27)

# %%
cami_air <- ggarrange(air_s4_refined[[1]] + labs(y="Completeness"), air_s7_refined[[1]], air_s8_refined[[1]], air_s9_refined[[1]], air_s10_refined[[1]], 
                     air_s4_refined[[2]] + labs(y="Contamination"), air_s7_refined[[2]], air_s8_refined[[2]], air_s9_refined[[2]], air_s10_refined[[2]], 
                      air_s11_refined[[1]] + labs(y="Completeness"), air_s12_refined[[1]], air_s23_refined[[1]], air_s26_refined[[1]], air_s27_refined[[1]],
                     air_s11_refined[[2]] + labs(y="Contamination"), air_s12_refined[[2]], air_s23_refined[[2]], air_s26_refined[[2]], air_s27_refined[[2]],
                     labels=c("4", "7", "8", "9", "10",
                              "4", "7", "8", "9", "10", 
                              "11", "12", "23", "26", "27", 
                              "11", "12", "23", "26", "27"),
                     ncol=5, nrow=4, common.legend=T, font.label = list(size = 10, face = "bold"))
cami_air
ggsave("cami_air_per_sample.png", units="in", width=10, height=11, dpi=600)
# Out:
# plot without title

# %%
s4_all <-fread('/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4/data/all_bins/checkm.out')

s4_all[`Bin Id` %like% 'rosella' & Completeness >= 90]
# Out:
# Warning message in fread("/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/sample_4/data/all_bins/checkm.out"):
# “Discarded single-line footer: <<[2021-05-25 06:11:12] INFO: { Current stage: 0:03:12.506 || Total: 3:13:34.898 }>>”
#    Bin Id           Marker lineage                   # genomes # markers
# 1  rosella_bin.11   o__Actinomycetales (UID1812)      229       457
# 2  rosella_bin.1100 g__Staphylococcus (UID301)         45       940
# 3  rosella_bin.1216 root (UID1)                      5656        56
# 4  rosella_bin.1252 root (UID1)                      5656        56
# 5  rosella_bin.1253 g__Staphylococcus (UID294)         60       773
# 6  rosella_bin.1277 g__Streptococcus (UID559)         118       610
# 7  rosella_bin.1282 c__Gammaproteobacteria (UID4387)  965       277
# 8  rosella_bin.1283 o__Actinomycetales (UID1812)      229       457
# 9  rosella_bin.1284 o__Lactobacillales (UID543)       294       471
# 10 rosella_bin.1285 c__Bacilli (UID285)               586       318
# 11 rosella_bin.15   o__Flavobacteriales (UID2815)     123       324
# 12 rosella_bin.18   root (UID1)                      5656        56
# 13 rosella_bin.185  k__Bacteria (UID203)             5449       102
# 14 rosella_bin.19   c__Gammaproteobacteria (UID4202)   67       481
# 15 rosella_bin.23   o__Clostridiales (UID1125)        128       313
# 16 rosella_bin.25   o__Pseudomonadales (UID4488)      185       813
# 17 rosella_bin.27   k__Bacteria (UID203)             5449       103
# 18 rosella_bin.31   k__Bacteria (UID203)             5449       102
# 19 rosella_bin.313  g__Staphylococcus (UID298)         56       805
# 20 rosella_bin.314  g__Staphylococcus (UID298)         56       805
# 21 rosella_bin.35   root (UID1)                      5656        56
# 22 rosella_bin.350  o__Actinomycetales (UID1812)      229       457
# 23 rosella_bin.354  o__Actinomycetales (UID1812)      229       457
# 24 rosella_bin.39   k__Bacteria (UID2570)             433       273
# 25 rosella_bin.4    root (UID1)                      5656        56
# 26 rosella_bin.44   k__Bacteria (UID203)             5449       103
# 27 rosella_bin.45   k__Bacteria (UID203)             5449       104
# 28 rosella_bin.46   s__algicola (UID2847)              33       496
# 29 rosella_bin.47   o__Flavobacteriales (UID2815)     123       324
# 30 rosella_bin.51   root (UID1)                      5656        56
# 31 rosella_bin.528  k__Bacteria (UID203)             5449       104
# 32 rosella_bin.56   k__Bacteria (UID203)             5449       104
# 33 rosella_bin.57   root (UID1)                      5656        56
# 34 rosella_bin.573  g__Neisseria (UID3907)             44       956
# 35 rosella_bin.58   g__Bacillus (UID865)               36      1200
# 36 rosella_bin.61   k__Bacteria (UID203)             5449       104
# 37 rosella_bin.66   k__Bacteria (UID203)             5449       104
# 38 rosella_bin.695  k__Bacteria (UID203)             5449       104
# 39 rosella_bin.797  o__Actinomycetales (UID1812)      229       457
# 40 rosella_bin.8    o__Sphingomonadales (UID3310)      26       569
# 41 rosella_bin.801  g__Staphylococcus (UID294)         60       773
# 42 rosella_bin.804  root (UID1)                      5656        56
# 43 rosella_bin.87   k__Bacteria (UID203)             5449       104
# 44 rosella_bin.924  root (UID1)                      5656        56
# 45 rosella_bin.958  f__Moraxellaceae (UID4680)         86       688
#    # marker sets 0  1    2   3  4  5+ Completeness Contamination
# 1  227            3  451   0  3  0  0  99.34         0.26
# 2  178            5  813  53 43 26  0  99.40        19.00
# 3   24            0    0   0 47  9  0 100.00       229.17
# 4   24            0    0   0 16 30 10 100.00       320.83
# 5  178            2  697  59 15  0  0  99.73        11.58
# 6  282            0  309 298  3  0  0 100.00        55.47
# 7  177            0  277   0  0  0  0 100.00         0.00
# 8  227            2  454   1  0  0  0  99.12         0.44
# 9  264            1  470   0  0  0  0  99.81         0.00
# 10 174            4  314   0  0  0  0  98.28         0.00
# 11 204            3  321   0  0  0  0  99.25         0.00
# 12  24            1    0   2 51  2  0  99.54       202.86
# 13  57            0   60  22 11  2  7 100.00        47.96
# 14 276           19  458   4  0  0  0  97.79         0.59
# 15 164           22  285   6  0  0  0  93.75         1.98
# 16 308           44  766   3  0  0  0  93.90         0.76
# 17  58            0    1  12 89  1  0 100.00       179.66
# 18  57            7   46  35 14  0  0  93.33        51.90
# 19 176            3  801   1  0  0  0  99.61         0.14
# 20 176            3  802   0  0  0  0  99.61         0.00
# 21  24            0    0  23 20 13  0 100.00       232.39
# 22 227            3  390  63  1  0  0  99.12        16.24
# 23 227            2  455   0  0  0  0  99.34         0.00
# 24 183            6  266   1  0  0  0  97.27         0.27
# 25  24            0    0  56  0  0  0 100.00       100.00
# 26  57            1    2  97  3  0  0  98.25       101.75
# 27  58            0   40  38 25  1  0 100.00       122.90
# 28 263            4  489   3  0  0  0  99.05         1.14
# 29 204            1  131 185  6  1  0  99.51        68.63
# 30  24            0    0  28 24  4  0 100.00       168.75
# 31  58            1    8  31 15 14 35  99.84       369.95
# 32  58            0   31  70  2  1  0 100.00        94.83
# 33  24            0    0  39 17  0  0 100.00       158.71
# 34 479           16  228 708  3  1  0  99.55        77.11
# 35 269           49 1148   3  0  0  0  94.51         0.09
# 36  58            0    2  18 13 36 35 100.00       243.63
# 37  58           11   47  45  1  0  0  96.71        29.31
# 38  58            0   50  53  1  0  0 100.00        29.31
# 39 227            3  454   0  0  0  0  99.52         0.00
# 40 293            2  564   3  0  0  0  99.59         0.77
# 41 178            1  228 542  2  0  0  99.81        67.15
# 42  24            0    0   0  0 15 41 100.00       341.67
# 43  58            0    8  58 17 15  6 100.00       156.43
# 44  24            0    0   7  4 43  2 100.00       237.50
# 45 364            0  687   1  0  0  0 100.00         0.04
#    Strain heterogeneity
# 1    0.00
# 2   98.22
# 3  100.00
# 4  100.00
# 5   44.23
# 6   97.07
# 7    0.00
# 8    0.00
# 9    0.00
# 10   0.00
# 11   0.00
# 12  73.05
# 13  93.43
# 14   0.00
# 15   0.00
# 16   0.00
# 17  98.25
# 18 100.00
# 19   0.00
# 20   0.00
# 21  96.89
# 22  98.48
# 23   0.00
# 24   0.00
# 25 100.00
# 26  16.04
# 27  99.16
# 28  66.67
# 29  20.10
# 30 100.00
# 31  78.31
# 32  92.68
# 33  94.44
# 34  97.65
# 35   0.00
# 36  85.25
# 37   4.17
# 38  67.86
# 39   0.00
# 40   0.00
# 41  30.47
# 42 100.00
# 43  96.91
# 44  94.61
# 45   0.00
