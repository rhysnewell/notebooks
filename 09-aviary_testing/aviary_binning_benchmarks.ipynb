# %%
library(data.table)
library(ggplot2)
library(dplyr)
library(viridis)
library(stringr)
theme_set(theme_bw())
source("setup.R")

# %%
cami_low <- generate_plots('/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/00-low_complexity/benchmark_aviary/', '/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/00-low_complexity/metawrap_refine')
cami_med <- generate_plots('/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/01-med_complexity/benchmark_aviary/', '/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/01-med_complexity/metawrap_refine')
cami_hi <- generate_plots('/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/02-hi_complexity/benchmark_aviary/', '/work2/microbiome/abisko/rhys/01-projects/09-simulated_metagenomes/03-CAMI_one/02-hi_complexity/metawrap_refine')
# Out:
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# ...

# %%
ggarrange(
    cami_low[[1]] + labs(y = "Completeness (%)"), cami_med[[1]], cami_hi[[1]], 
    cami_low[[2]] + labs(y = "Contamination (%)"), cami_med[[2]], cami_hi[[2]], 
    labels = c("A)", "B)", "C)"),
    common.legend=T,
    font.label=list(size=10)
)
ggsave("cami_one_all.png", width=10, height=8, dpi=600)
# Out:
# plot without title

# %%
cami_low[[3]]
cami_med[[3]]
cami_hi[[3]]
# Out:
#   binner   t1 t2 t3 t4 t5
# 1 ATLAS    15 18 18 19 21
# 2 Aviary   17 22 26 26 31
# 3 DASTool  17 22 24 24 26
# 4 MetaWRAP 16 20 21 23 26
#   binner   t1 t2  t3  t4  t5
# 1 ATLAS    92  97  98  99 102
# 2 Aviary   97 101 101 102 106
# 3 DASTool  97 101 101 101 104
# 4 MetaWRAP 94  96 100 102 104
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    344 370 383 386 391
# 2 Aviary   423 459 473 482 504
# 3 DASTool  409 441 457 461 463
# 4 MetaWRAP 370 398 418 423 429

# %%
gi_s0 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_0/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_0/refine/')
gi_s1 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_1/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_1/refine/')
gi_s2 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_2/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_2/refine/')
gi_s3 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_3/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_3/refine/')
gi_s4 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_4/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_4/refine/')
gi_s5 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_5/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_5/refine/')
gi_s9 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_9/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_9/refine/')
gi_s10 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_10/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_10/refine/')
gi_s11 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_11/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_11/refine/')
gi_s12 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_12/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_12/refine/')

gi_all <- get_total_plots(list(gi_s0, gi_s1, gi_s2, gi_s3, gi_s4, gi_s5, gi_s9, gi_s10, gi_s11, gi_s12))
# Out:
# Error in fread(aviary_checkm): File '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_0//bins/checkm.out' does not exist or is non-readable. getwd()=='/mnt/home/n10853499/00-jupyter/09-aviary_testing'
# Traceback:
#
# 1. generate_plots("/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/binning_sample_0/",
#  .     "/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_gi/binning/metawrap/sample_0/refine/")
# 2. fread(aviary_checkm)
# 3. stop("File '", file, "' does not exist or is non-readable. getwd()=='",
#  .     getwd(), "'")

# %%
gi_all[[3]]
# Out:
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    220 231 242 249 256
# 2 Aviary   364 387 409 420 439
# 3 DASTool  332 352 369 379 391
# 4 MetaWRAP 196 207 219 223 229

# %%
uro_s0 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_0/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_0/refine')
uro_s2 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_2/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_2/refine')
uro_s3 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_3/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_3/refine')
uro_s5 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_5/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_5/refine')
uro_s6 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_6/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_6/refine')
uro_s21 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_21/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_21/refine')
uro_s22 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_22/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_22/refine')
uro_s24 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_24/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_24/refine')
uro_s25 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/binning_sample_25/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_uro/binning/metawrap/sample_25/refine')

uro_all <- get_total_plots(list(uro_s0, uro_s2, uro_s3, uro_s5, uro_s6, uro_s21, uro_s22, uro_s24, uro_s25))

# %%
uro_all[[3]]
# Out:
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    187 208 218 222 230
# 2 Aviary   258 294 314 327 346
# 3 DASTool  238 266 281 290 308
# 4 MetaWRAP 161 178 188 192 200

# %%
skin_s1 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_1/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_1/refine')
skin_s13 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_13/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_13/refine')
skin_s14 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_14/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_14/refine')
skin_s15 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_15/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_15/refine')
skin_s16 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_16/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_16/refine')
skin_s17 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_17/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_17/refine')
skin_s18 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_18/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_18/refine')
skin_s19 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_19/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_19/refine')
skin_s20 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_20/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_20/refine')
skin_s28 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/binning_sample_28/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Skin/binning/metawrap/sample_28/refine')

skin_all <- get_total_plots(list(skin_s1, skin_s13, skin_s14, skin_s15, skin_s16, skin_s17, skin_s18, skin_s19, skin_s20, skin_s28))

# %%
skin_all[[3]]
# Out:
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    222 241 262 274 290
# 2 Aviary   424 480 513 535 608
# 3 DASTool  375 411 439 455 484
# 4 MetaWRAP 207 229 241 249 274

# %%
oral_s6 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_6/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_6/refine')
oral_s7 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_7/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_7/refine')
oral_s8 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_8/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_8/refine')
oral_s13 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_13/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_13/refine')
oral_s14 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_14/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_14/refine')
oral_s15 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_15/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_15/refine')
oral_s16 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_16/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_16/refine')
oral_s17 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_17/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_17/refine')
oral_s18 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_18/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_18/refine')
oral_s19 <- generate_plots('/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/binning_sample_19/', '/lustre/scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Oral/binning/metawrap/sample_19/refine')

oral_all <- get_total_plots(list(oral_s6, oral_s7, oral_s8, oral_s13, oral_s14, oral_s15, oral_s16, oral_s17, oral_s18, oral_s19))

# %%
oral_all[[3]]
# Out:
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    330 361 396 413 477
# 2 Aviary   517 615 700 751 885
# 3 DASTool  456 511 566 597 668
# 4 MetaWRAP 285 324 358 385 431

# %%
air_s4 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_4/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_4/refine/')
air_s7 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_7/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_7/refine/')
air_s8 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_8/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_8/refine/')
air_s9 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_9/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_9/refine/')
air_s10 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_10/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_10/refine/')
air_s11 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_11/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_11/refine/')
air_s12 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_12/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_12/refine/')
air_s23 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_23/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_23/refine/')
air_s26 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_26/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_26/refine/')
air_s27 <- generate_plots('//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/binning_sample_27/', '//scratch/microbiome/n10853499/00-rosella_testing/01-CAMI_II/CAMI_Airways/binning/metawrap/sample_27/refine/')

air_all <- get_total_plots(list(air_s4, air_s7, air_s8, air_s10, air_s11, air_s12, air_s23, air_s27))

# %%
air_all[[3]]
# Out:
#   binner   t1  t2  t3  t4  t5
# 1 ATLAS    188 203 210 251 299
# 2 Aviary   307 351 388 449 533
# 3 DASTool  263 288 315 369 424
# 4 MetaWRAP 159 171 194 228 264

# %%
cami_total <- ggarrange(gi_all[[1]] + labs(y="Completeness"), skin_all[[1]], uro_all[[1]], oral_all[[1]], air_all[[1]],
                        gi_all[[2]] + labs(y="Contamination"), skin_all[[2]], uro_all[[2]], oral_all[[2]], air_all[[2]], 
                        labels=c("A)", "B)", "C)", "D)", "E)"),
                        ncol=5, nrow=2, common.legend=T, font.label = list(size = 10, face = "bold"))
cami_total
ggsave("cami_totals_per_sample.png", units="in", width=10, height=6, dpi=600)

# %%
aale <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalE_18-Q3-R2-46/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/AalE_18-Q3-R2-46/refine')
aalw <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalW_18-Q3-R10-53/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/AalW_18-Q3-R10-53/refine')
aved <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Aved_18-Q3-R54-62/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Aved_18-Q3-R54-62/refine')
bjer <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Bjer_18-Q3-R1-45/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Bjer_18-Q3-R1-45/refine')
ejby <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ejby_18-Q3-R6-50/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ejby_18-Q3-R6-50/refine')
damh <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Damh_18-Q3-R51-60/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Damh_18-Q3-R51-60/refine')
esbe <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/EsbE_18-Q3-R3-47/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/EsbE_18-Q3-R3-47/refine')
esbw <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/EsbW_18-Q3-R4-48/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/EsbW_18-Q3-R4-48/refine')
ega <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ega_18-Q3-R5-49/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ega_18-Q3-R5-49/refine')
fred <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Fred_18-Q3-R57-64/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Fred_18-Q3-R57-64/refine')
hirt <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hirt_18-Q3-R61-65/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hirt_18-Q3-R61-65/refine')
hjor <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hjor_18-Q3-R7-51/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hjor_18-Q3-R7-51/refine')
kalu <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Kalu_18-Q3-R12-55/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Kalu_18-Q3-R12-55/refine')
mari <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Mari_18-Q3-R65-66/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Mari_18-Q3-R65-66/refine')
odnw <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/OdNW_18-Q3-R42-56/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/OdNW_18-Q3-R42-56/refine')
rand <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Rand_18-Q3-R56-63/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Rand_18-Q3-R56-63/refine')
ribe <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ribe_18-Q3-R11-54/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ribe_18-Q3-R11-54/refine')
skiv <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Skiv_18-Q3-R9-52/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Skiv_18-Q3-R9-52/refine')
vibo <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Vibo_18-Q3-R45-57/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Vibo_18-Q3-R45-57/refine')
viby <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Viby_18-Q3-R106-67/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Viby_18-Q3-R106-67/refine')
odne <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/OdNE_18-Q3-R46-58/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/OdNE_18-Q3-R46-58/refine')
hade <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hade_18-Q3-R52-61/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hade_18-Q3-R52-61/refine')
lyne <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Lyne_18-Q3-R50-59/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Lyne_18-Q3-R50-59/refine')

aale_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalE_18-Q3-R2-46_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/AalE_18-Q3-R2-46_All_short/refine')
aalw_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalW_18-Q3-R10-53_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/AalW_18-Q3-R10-53_All_short/refine')
aved_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Aved_18-Q3-R54-62_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Aved_18-Q3-R54-62_All_short/refine')
bjer_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Bjer_18-Q3-R1-45_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Bjer_18-Q3-R1-45_All_short/refine')
ejby_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ejby_18-Q3-R6-50_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ejby_18-Q3-R6-50_All_short/refine')
damh_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Damh_18-Q3-R51-60_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Damh_18-Q3-R51-60_All_short/refine')
esbe_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/EsbE_18-Q3-R3-47_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/EsbE_18-Q3-R3-47_All_short/refine')
esbw_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/EsbW_18-Q3-R4-48_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/EsbW_18-Q3-R4-48_All_short/refine')
ega_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ega_18-Q3-R5-49_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ega_18-Q3-R5-49_All_short/refine')
fred_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Fred_18-Q3-R57-64_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Fred_18-Q3-R57-64_All_short/refine')
hirt_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hirt_18-Q3-R61-65_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hirt_18-Q3-R61-65_All_short/refine')
hjor_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hjor_18-Q3-R7-51_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hjor_18-Q3-R7-51_All_short/refine')
kalu_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Kalu_18-Q3-R12-55_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Kalu_18-Q3-R12-55_All_short/refine')
mari_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Mari_18-Q3-R65-66_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Mari_18-Q3-R65-66_All_short/refine')
odnw_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/OdNW_18-Q3-R42-56_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/OdNW_18-Q3-R42-56_All_short/refine')
rand_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Rand_18-Q3-R56-63_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Rand_18-Q3-R56-63_All_short/refine')
ribe_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Ribe_18-Q3-R11-54_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Ribe_18-Q3-R11-54_All_short/refine')
skiv_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Skiv_18-Q3-R9-52_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Skiv_18-Q3-R9-52_All_short/refine')
vibo_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Vibo_18-Q3-R45-57_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Vibo_18-Q3-R45-57_All_short/refine')
viby_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Viby_18-Q3-R106-67_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Viby_18-Q3-R106-67_All_short/refine')
odne_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/OdNE_18-Q3-R46-58_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/OdNE_18-Q3-R46-58_All_short/refine')
hade_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Hade_18-Q3-R52-61_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Hade_18-Q3-R52-61_All_short/refine')
lyne_all <- generate_plots('/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/Lyne_18-Q3-R50-59_All_short/', '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/Lyne_18-Q3-R50-59_All_short/refine')
# Out:
# Error in fread(atlas_checkm): File '/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalE_18-Q3-R2-46/data/atlas_dastool/checkm.out' does not exist or is non-readable. getwd()=='/mnt/home/n10853499/00-jupyter/09-aviary_testing'
# Traceback:
#
# 1. generate_plots("/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/AalE_18-Q3-R2-46/",
#  .     "/mnt/hpccs01/scratch/microbiome/n10853499/00-rosella_testing/02-activated_sludge/assembly/metawrap/AalE_18-Q3-R2-46/refine")
# 2. fread(atlas_checkm)
# 3. stop("File '", file, "' does not exist or is non-readable. getwd()=='",
#  .     getwd(), "'")

# %%
aale[[3]]
aalw[[3]]
aved[[3]]
bjer[[3]]
# Out:
#   binner   t1 t2 t3 t4 t5
# 1 ATLAS    3  13 40 59  98
# 2 Aviary   4  15 44 66 115
# 3 DASTool  4  15 44 64 110
# 4 MetaWRAP 4  12 33 49  98
#   binner   t1 t2 t3 t4  t5
# 1 ATLAS    13 37 78 104 171
# 2 Aviary   14 42 92 127 211
# 3 DASTool  13 41 88 122 193
# 4 MetaWRAP 14 32 73 106 162
#   binner   t1 t2 t3 t4  t5
# 1 ATLAS    11 40 88 123 196
# 2 Aviary   13 44 95 135 215
# 3 DASTool  13 43 94 134 213
# 4 MetaWRAP 11 35 84 112 184
#   binner   t1 t2 t3 t4 t5
# 1 ATLAS    7  22 43 64 111
# 2 Aviary   7  23 44 67 128
# 3 DASTool  7  23 43 65 119
# 4 MetaWRAP 8  25 39 55 108

# %%
total_plots <- get_total_plots(list(
    aale, 
    aalw, 
    aved, 
    bjer, 
    ejby, 
    damh, 
    esbe, 
    esbw, 
    ega, 
    fred, 
    hirt,
    hjor, 
    kalu,
    mari, 
    odnw, 
    rand, 
    ribe, 
    skiv, 
    vibo,
    viby,
    hade,
    odne,
    lyne
))

total_plots_all_short <- get_total_plots(list(
    aale_all, 
    aalw_all, 
    aved_all, 
    bjer_all, 
    ejby_all, 
    damh_all, 
    esbe_all, 
    esbw_all, 
    ega_all, 
    fred_all, 
    hirt_all,
    hjor_all, 
    kalu_all,
    mari_all, 
    odnw_all, 
    rand_all, 
    ribe_all, 
    skiv_all, 
    vibo_all,
    viby_all,
    hade_all,
    odne_all,
    lyne_all
))
# Out:
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# ...

# %%
combined <- get_total_plots(list(total_plots, total_plots_all_short))
# Out:
# Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t2, N)):
# “Invalid .internal.selfref detected and fixed by taking a (shallow) copy of the data.table so that := can add this new column by reference. At an earlier point, this data.table has been copied by R (or was created manually using structure() or similar). Avoid names<- and attr<- which in R currently (and oddly) may copy the whole data.table. Use set* syntax instead to avoid copying: ?set, ?setnames and ?setattr. If this message doesn't help, please report your use case to the data.table issue tracker so the root cause can be fixed or this message improved.”Joining, by = "binner"
# Warning message in `[.data.table`(output, , `:=`(t3, N)):
# ...

# %%
# total_plots[[1]]
combined[[3]]
ggarrange(combined[[1]] + labs(y="Completion (%)"), combined[[2]] + labs(y="Contamination (%)"), common.legend=T, labels=c("A)", "B)"))
ggsave("activated_sludge_binning.png", width=8, height=6, dpi=600)
# Out:
#   binner   t1  t2   t3   t4   t5
# 1 ATLAS    445 1254 2620 3793 6209
# 2 Aviary   461 1299 2807 4193 7095
# 3 DASTool  457 1274 2741 4039 6687
# 4 MetaWRAP 335  895 1858 2746 4801
# plot without title
