# %%
library(data.table)
library(ggplot2)
library(ggpubr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
process_stats <- function(results, file_structure= '/www/metaquast/summary/TSV/Genome_fraction.tsv') {
    stats <- lapply(results, function(x) {
        result <- fread(paste0(x, file_structure))

        result$sample <- gsub('\\/', '', tstrsplit(x, 'metaquast/', keep=2L))

        return(result)
    })
#     stats <- do.call(rbind, stats)
#     stats <- melt(stats, id.vars=c("Assemblies", "sample"))
#     stats <- transform(stats, value = as.numeric(value))
#     stats[, value:=ifelse(is.na(value), 0.0, value)]
    return(stats)

}

get_quast_stats <- function(directory = "/mnt/hpccs01/scratch/microbiome/n10853499/02-lorikeet_testing/00-STRONG_sim/Synth_G45_S03D/09-metaquast") {
    results <- list.dirs(directory, recursive=FALSE)
#     print(results)
    num_indels <- process_stats(results, '/www/metaquast/summary/TSV/num_indels_per_100_kbp.tsv')
    num_mismatches <- process_stats(results, '/www/metaquast/summary/TSV/num_mismatches_per_100_kbp.tsv')
    num_misassemblies <- process_stats(results, '/www/metaquast/summary/TSV/num_misassemblies.tsv')
    
    
    return(list("indels"=num_indels, "mismatches"=num_mismatches, "misassemblies"=num_misassemblies))
}

# %%
synth_03 <- get_quast_stats()
synth_03$mismatches
# Out:
# [[1]]
#      Assemblies 1028801_0seq_strain_0       sample
# 1: 1028801_0seq                     0 1028801_0seq
#
# [[2]]
#      Assemblies 1031711_0seq_strain_0 1031711_0seq_strain_1
# 1: 1031711_0seq                 25.45                284.13
# 2:    305_14seq                     -               2323.57
# 3:    305_15seq                     -               1126.99
# 4:    305_16seq                     -               2388.34
# 5:  859656_0seq                     -               3328.02
#    1031711_0seq_strain_2       sample
# 1:                317.09 1031711_0seq
# 2:                     - 1031711_0seq
# 3:                879.47 1031711_0seq
# 4:               2735.25 1031711_0seq
# 5:                     - 1031711_0seq
#
# [[3]]
#      Assemblies 1037915_0seq_strain_0 1037915_0seq_strain_1       sample
# 1: 1037915_0seq                249.60                206.21 1037915_0seq
# 2: 1038921_0seq               4486.34                     - 1037915_0seq
# 3:  587753_1seq               1353.89                     - 1037915_0seq
# 4:   86192_0seq               2634.44                     - 1037915_0seq
#
# [[4]]
#      Assemblies 1079988_0seq_strain_0       sample
# 1: 1079988_0seq                     0 1079988_0seq
#
# [[5]]
#      Assemblies 1081646_0seq_strain_0       sample
# 1: 1081646_0seq                606.05 1081646_0seq
# 2: 1234596_0seq                     - 1081646_0seq
# 3: 1421551_0seq                     - 1081646_0seq
#
# [[6]]
#      Assemblies 1095774_0seq_strain_0 1095774_0seq_strain_1       sample
# 1: 1095774_0seq                255.92                  0.00 1095774_0seq
# 2: 1123863_0seq                     -                     - 1095774_0seq
# 3:  706191_0seq                     -                     - 1095774_0seq
# 4:  932677_0seq                     -                     - 1095774_0seq
#
# [[7]]
#      Assemblies 1124991_0seq_strain_0       sample
# 1: 1124991_0seq                     0 1124991_0seq
#
# [[8]]
#      Assemblies 1124992_0seq_strain_0 1124992_0seq_strain_1       sample
# 1: 1124992_0seq                 70.09                  0.00 1124992_0seq
# 2:   40480_1seq                     -                     - 1124992_0seq
#
# [[9]]
#      Assemblies 1132501_0seq_strain_0 1132501_0seq_strain_1
# 1: 1132501_0seq                 23.68                 40.06
# 2:  427317_0seq                     -                     -
# 3:  429572_0seq                     -                     -
# 4:  930943_0seq                     -                     -
#    1132501_0seq_strain_2 1132501_0seq_strain_3       sample
# 1:                112.95                  0.00 1132501_0seq
# 2:                     -                     - 1132501_0seq
# 3:                     -                     - 1132501_0seq
# 4:                     -                     - 1132501_0seq
#
# [[10]]
#      Assemblies 1136179_0seq_strain_0 1136179_0seq_strain_1       sample
# 1: 1136179_0seq                618.30                  0.00 1136179_0seq
# 2: 1289591_0seq               1226.21                     - 1136179_0seq
# 3:  234621_0seq               1433.86                     - 1136179_0seq
#
# [[11]]
#      Assemblies 1159201_0seq_strain_0 1159201_0seq_strain_2       sample
# 1: 1159201_0seq                493.06                  0.00 1159201_0seq
# 2:  708616_0seq               2077.25                     - 1159201_0seq
# 3:  710128_0seq               1616.57                     - 1159201_0seq
#
# [[12]]
#      Assemblies 1167634_0seq_strain_0 1167634_0seq_strain_1       sample
# 1: 1167634_0seq                 31.12                  0.00 1167634_0seq
# 2:  562971_1seq               1260.01               1297.06 1167634_0seq
#
# [[13]]
#      Assemblies 1172205_1seq_strain_0 1172205_1seq_strain_1       sample
# 1: 1172205_1seq                  2.54                  0.05 1172205_1seq
# 2: 1247646_0seq                     -                     - 1172205_1seq
# 3: 1247648_0seq                     -                     - 1172205_1seq
# 4: 1266729_0seq                     -                     - 1172205_1seq
#
# [[14]]
#      Assemblies 1184254_0seq_strain_0       sample
# 1: 1184254_0seq                     0 1184254_0seq
#
# [[15]]
#      Assemblies 1187956_0seq_strain_0 1187956_0seq_strain_1       sample
# 1: 1187956_0seq                 86.66                  0.00 1187956_0seq
# 2:    1308_0seq                     -                     - 1187956_0seq
# 3:    1308_1seq                     -                     - 1187956_0seq
# 4:  264199_0seq                     -                     - 1187956_0seq
# 5:  767463_0seq                     -                     - 1187956_0seq
#
# [[16]]
#      Assemblies 1228997_0seq_strain_0 1228997_0seq_strain_1       sample
# 1: 1228997_0seq                819.39                  0.00 1228997_0seq
# 2: 1271752_0seq                     -                     - 1228997_0seq
# 3: 1455062_0seq                     -                     - 1228997_0seq
# 4:  693978_0seq                     -                     - 1228997_0seq
# 5:  992406_0seq                     -                     - 1228997_0seq
#
# [[17]]
#      Assemblies 1230587_0seq_strain_0 1230587_0seq_strain_1       sample
# 1: 1230587_0seq                333.65                  0.00 1230587_0seq
# 2:  698936_0seq                214.94                     - 1230587_0seq
#
# [[18]]
#      Assemblies 1239783_0seq_strain_0 1239783_0seq_strain_1       sample
# 1: 1239783_0seq                  4.85                  0.00 1239783_0seq
# 2:  720555_0seq                     -                     - 1239783_0seq
#
# [[19]]
#      Assemblies 1293904_0seq_strain_0 1293904_0seq_strain_1
# 1: 1293904_0seq                  1.91                  0.64
# 2: 1293906_0seq                744.37                746.75
# 3: 1293907_0seq                690.71                685.30
# 4: 1293910_0seq                508.88                512.45
#    1293904_0seq_strain_3       sample
# 1:                  0.00 1293904_0seq
# 2:                747.15 1293904_0seq
# 3:                683.60 1293904_0seq
# 4:                511.59 1293904_0seq
#
# [[20]]
#      Assemblies 1381124_0seq_strain_0       sample
# 1: 1381124_0seq                     0 1381124_0seq
#
# [[21]]
#      Assemblies 1392005_0seq_strain_0 1392005_0seq_strain_2       sample
# 1: 1392005_0seq                  0.43                  0.18 1392005_0seq
# 2:  399795_0seq                     -                     - 1392005_0seq
#
# [[22]]
#    Assemblies 1402_2seq_strain_0 1402_2seq_strain_1    sample
# 1:  1402_2seq             892.75               0.00 1402_2seq
# 2:  1402_3seq                  -                  - 1402_2seq
#
# [[23]]
#      Assemblies 1434109_0seq_strain_0 1434109_0seq_strain_2
# 1: 1434109_0seq                  0.51                  0.16
# 2:  796385_0seq                     -                     -
#    1434109_0seq_strain_3 1434109_0seq_strain_4 1434109_0seq_strain_5
# 1:                  0.12                  0.86                  0.12
# 2:                     -                     -                     -
#          sample
# 1: 1434109_0seq
# 2: 1434109_0seq
#
# [[24]]
#      Assemblies 1434114_0seq_strain_0 1434114_0seq_strain_1       sample
# 1: 1434114_0seq                137.66                  0.00 1434114_0seq
# 2: 1434115_0seq               1057.23                     - 1434114_0seq
# 3: 1434117_0seq                902.04                     - 1434114_0seq
# 4:  192952_0seq                     -                     - 1434114_0seq
# 5:  213585_0seq                733.46                     - 1434114_0seq
#
# [[25]]
#      Assemblies 1435057_0seq_strain_0       sample
# 1: 1435057_0seq                     0 1435057_0seq
#
# [[26]]
#      Assemblies 1452724_0seq_strain_0 1452724_0seq_strain_1
# 1: 1452724_0seq                 22.87                  1.47
# 2:  96345_11seq                     -                     -
# 3:   96345_5seq                     -                     -
#    1452724_0seq_strain_2       sample
# 1:                  0.00 1452724_0seq
# 2:                     - 1452724_0seq
# 3:                     - 1452724_0seq
#
# [[27]]
#      Assemblies 1454377_0seq_strain_0       sample
# 1: 1454377_0seq                     0 1454377_0seq
#
# [[28]]
#     Assemblies 1681_5seq_strain_0 1681_5seq_strain_2    sample
# 1:   1681_5seq               2.45               0.00 1681_5seq
# 2: 398513_1seq             691.49                  - 1681_5seq
# 3: 500634_2seq             690.05                  - 1681_5seq
# 4: 702459_0seq               5.16                  - 1681_5seq
# 5: 883062_0seq             737.25                  - 1681_5seq
#
# [[29]]
#     Assemblies 227377_0seq_strain_0 227377_0seq_strain_2      sample
# 1: 227377_0seq                30.35                 0.34 227377_0seq
# 2: 360115_0seq               136.65                    - 227377_0seq
# 3: 434924_0seq               337.24                    - 227377_0seq
#
# [[30]]
#    Assemblies 2287_1seq_strain_0 2287_1seq_strain_2    sample
# 1:  2287_1seq               0.29                  0 2287_1seq
#
# [[31]]
#     Assemblies 272947_0seq_strain_0      sample
# 1: 272947_0seq                    0 272947_0seq
#
# [[32]]
#     Assemblies 315750_0seq_strain_0      sample
# 1: 315750_0seq                    0 315750_0seq
#
# [[33]]
#    Assemblies 33966_0seq_strain_0 33966_0seq_strain_1     sample
# 1: 33966_0seq                0.05                   0 33966_0seq
#
# [[34]]
#     Assemblies 369723_0seq_strain_0      sample
# 1: 369723_0seq                    0 369723_0seq
#
# [[35]]
#    Assemblies 375_0seq_strain_0 375_0seq_strain_1 375_0seq_strain_2   sample
# 1:   375_0seq              0.09              0.13                 0 375_0seq
#
# [[36]]
#     Assemblies 416269_0seq_strain_0 416269_0seq_strain_1      sample
# 1: 416269_0seq              1159.21                 0.00 416269_0seq
# 2: 537457_0seq               274.87                    - 416269_0seq
#
# [[37]]
#    Assemblies 438_0seq_strain_0   sample
# 1:   438_0seq                 0 438_0seq
#
# [[38]]
#     Assemblies 444178_0seq_strain_0      sample
# 1: 444178_0seq                    0 444178_0seq
#
# [[39]]
#     Assemblies 498217_0seq_strain_0 498217_0seq_strain_1      sample
# 1: 498217_0seq                    0                    0 498217_0seq
#
# [[40]]
#     Assemblies 523841_2seq_strain_0      sample
# 1: 523841_2seq                 0.00 523841_2seq
# 2: 523841_3seq                    - 523841_2seq
#
# [[41]]
#     Assemblies 575606_0seq_strain_0      sample
# 1: 575606_0seq                    0 575606_0seq
#
# [[42]]
#     Assemblies 617121_0seq_strain_0      sample
# 1: 617121_0seq                    0 617121_0seq
#
# [[43]]
#     Assemblies 712961_0seq_strain_0      sample
# 1: 712961_0seq                    0 712961_0seq
#
# [[44]]
#     Assemblies 862965_0seq_strain_0      sample
# 1: 862965_0seq                    0 862965_0seq
